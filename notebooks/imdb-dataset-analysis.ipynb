# %% [markdown]
# Here I'm trying to analyze the [free datasets](https://developer.imdb.com/non-commercial-datasets/) provided by IMDB.

# %%
import pandas as pd

# %%
df_title_basics = pd.read_csv("../data/title.basics.tsv", sep="\t")
df_title_basics
# Out:
# /tmp/ipykernel_271612/3619878085.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_title_basics = pd.read_csv('../data/title.basics.tsv', sep='\t')
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11340742  tt9916848  tvEpisode              Episode #3.17
# 11340743  tt9916850  tvEpisode              Episode #3.19
# 11340744  tt9916852  tvEpisode              Episode #3.20
# 11340745  tt9916856      short                   The Wind
# 11340746  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              5
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 11340742              Episode #3.17       0      2009      \N             \N
# 11340743              Episode #3.19       0      2010      \N             \N
# 11340744              Episode #3.20       0      2010      \N             \N
# 11340745                   The Wind       0      2015      \N             27
# 11340746  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                              Short
# ...                              ...
# 11340742                       Drama
# 11340743                       Drama
# 11340744                       Drama
# 11340745                       Short
# 11340746  Adventure,Animation,Comedy
#
# [11340747 rows x 9 columns]

# %%
df_title_ratings = pd.read_csv("../data/title.ratings.tsv", sep="\t")
df_title_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2113
# 1        tt0000002            5.6       285
# 2        tt0000003            6.4      2147
# 3        tt0000004            5.3       183
# 4        tt0000005            6.2      2870
# ...            ...            ...       ...
# 1517428  tt9916730            7.0        12
# 1517429  tt9916766            7.1        24
# 1517430  tt9916778            7.2        37
# 1517431  tt9916840            6.9        11
# 1517432  tt9916880            7.9         9
#
# [1517433 rows x 3 columns]

# %%
df_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11340747 entries, 0 to 11340746
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 778.7+ MB

# %%
df = pd.merge(df_title_basics, df_title_ratings, how="inner", on="tconst")
df
# Out:
#             tconst  titleType                primaryTitle  \
# 0        tt0000001      short                  Carmencita
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short                Poor Pierrot
# 3        tt0000004      short                 Un bon bock
# 4        tt0000005      short            Blacksmith Scene
# ...            ...        ...                         ...
# 1517428  tt9916730      movie                      6 Gunn
# 1517429  tt9916766  tvEpisode              Episode #10.15
# 1517430  tt9916778  tvEpisode                      Escape
# 1517431  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 1517432  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              5
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 1517428                      6 Gunn       0      2017      \N            116
# 1517429              Episode #10.15       0      2019      \N             43
# 1517430                      Escape       0      2019      \N             \N
# 1517431  Horrid Henry's Comic Caper       0      2014      \N             11
# 1517432   Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres  averageRating  numVotes
# 0                  Documentary,Short            5.7      2113
# 1                    Animation,Short            5.6       285
# 2           Animation,Comedy,Romance            6.4      2147
# 3                    Animation,Short            5.3       183
# 4                              Short            6.2      2870
# ...                              ...            ...       ...
# 1517428                        Drama            7.0        12
# 1517429  Family,Game-Show,Reality-TV            7.1        24
# 1517430          Crime,Drama,Mystery            7.2        37
# 1517431   Adventure,Animation,Comedy            6.9        11
# 1517432   Adventure,Animation,Comedy            7.9         9
#
# [1517433 rows x 11 columns]

# %%
df["titleType"].unique()
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvEpisode', 'tvSeries',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
useful_title_types = ["movie", "tvMovie", "tvSeries", "tvMiniSeries"]
df = df[df["titleType"].isin(useful_title_types)]
df
# Out:
#             tconst titleType                   primaryTitle  \
# 8        tt0000009     movie                     Miss Jerry
# 144      tt0000147     movie  The Corbett-Fitzsimmons Fight
# 339      tt0000502     movie                       Bohemios
# 374      tt0000574     movie    The Story of the Kelly Gang
# 384      tt0000591     movie               The Prodigal Son
# ...            ...       ...                            ...
# 1517407  tt9916428     movie            The Secret of China
# 1517409  tt9916460   tvMovie                      Pink Taxi
# 1517413  tt9916538     movie            Kuambil Lagi Hatiku
# 1517426  tt9916706     movie                Dankyavar Danka
# 1517428  tt9916730     movie                         6 Gunn
#
#                          originalTitle isAdult startYear endYear  \
# 8                           Miss Jerry       0      1894      \N
# 144      The Corbett-Fitzsimmons Fight       0      1897      \N
# 339                           Bohemios       0      1905      \N
# 374        The Story of the Kelly Gang       0      1906      \N
# 384                  L'enfant prodigue       0      1907      \N
# ...                                ...     ...       ...     ...
# 1517407   Hong xing zhao yao Zhong guo       0      2019      \N
# 1517409                      Pink Taxi       0      2019      \N
# 1517413            Kuambil Lagi Hatiku       0      2019      \N
# 1517426                Dankyavar Danka       0      2013      \N
# 1517428                         6 Gunn       0      2017      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes
# 8                   45                     Romance            5.4       216
# 144                100      Documentary,News,Sport            5.2       544
# 339                100                          \N            4.4        18
# 374                 70  Action,Adventure,Biography            6.0       952
# 384                 90                       Drama            5.7        29
# ...                ...                         ...            ...       ...
# 1517407             \N       Adventure,History,War            3.6        19
# 1517409             \N                      Comedy            8.9        19
# 1517413            123                       Drama            8.3         9
# 1517426             \N                      Comedy            7.7         9
# 1517428            116                       Drama            7.0        12
#
# [497052 rows x 11 columns]

# %%
df = df.dropna()
df
# Out:
#             tconst titleType                   primaryTitle  \
# 8        tt0000009     movie                     Miss Jerry
# 144      tt0000147     movie  The Corbett-Fitzsimmons Fight
# 339      tt0000502     movie                       Bohemios
# 374      tt0000574     movie    The Story of the Kelly Gang
# 384      tt0000591     movie               The Prodigal Son
# ...            ...       ...                            ...
# 1517407  tt9916428     movie            The Secret of China
# 1517409  tt9916460   tvMovie                      Pink Taxi
# 1517413  tt9916538     movie            Kuambil Lagi Hatiku
# 1517426  tt9916706     movie                Dankyavar Danka
# 1517428  tt9916730     movie                         6 Gunn
#
#                          originalTitle isAdult startYear endYear  \
# 8                           Miss Jerry       0      1894      \N
# 144      The Corbett-Fitzsimmons Fight       0      1897      \N
# 339                           Bohemios       0      1905      \N
# 374        The Story of the Kelly Gang       0      1906      \N
# 384                  L'enfant prodigue       0      1907      \N
# ...                                ...     ...       ...     ...
# 1517407   Hong xing zhao yao Zhong guo       0      2019      \N
# 1517409                      Pink Taxi       0      2019      \N
# 1517413            Kuambil Lagi Hatiku       0      2019      \N
# 1517426                Dankyavar Danka       0      2013      \N
# 1517428                         6 Gunn       0      2017      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes
# 8                   45                     Romance            5.4       216
# 144                100      Documentary,News,Sport            5.2       544
# 339                100                          \N            4.4        18
# 374                 70  Action,Adventure,Biography            6.0       952
# 384                 90                       Drama            5.7        29
# ...                ...                         ...            ...       ...
# 1517407             \N       Adventure,History,War            3.6        19
# 1517409             \N                      Comedy            8.9        19
# 1517413            123                       Drama            8.3         9
# 1517426             \N                      Comedy            7.7         9
# 1517428            116                       Drama            7.0        12
#
# [497051 rows x 11 columns]

# %%
df["imdb_id"] = df["tconst"].apply(lambda x: int(x.lstrip("t")))
df
# Out:
#             tconst titleType                   primaryTitle  \
# 8        tt0000009     movie                     Miss Jerry
# 144      tt0000147     movie  The Corbett-Fitzsimmons Fight
# 339      tt0000502     movie                       Bohemios
# 374      tt0000574     movie    The Story of the Kelly Gang
# 384      tt0000591     movie               The Prodigal Son
# ...            ...       ...                            ...
# 1517407  tt9916428     movie            The Secret of China
# 1517409  tt9916460   tvMovie                      Pink Taxi
# 1517413  tt9916538     movie            Kuambil Lagi Hatiku
# 1517426  tt9916706     movie                Dankyavar Danka
# 1517428  tt9916730     movie                         6 Gunn
#
#                          originalTitle isAdult startYear endYear  \
# 8                           Miss Jerry       0      1894      \N
# 144      The Corbett-Fitzsimmons Fight       0      1897      \N
# 339                           Bohemios       0      1905      \N
# 374        The Story of the Kelly Gang       0      1906      \N
# 384                  L'enfant prodigue       0      1907      \N
# ...                                ...     ...       ...     ...
# 1517407   Hong xing zhao yao Zhong guo       0      2019      \N
# 1517409                      Pink Taxi       0      2019      \N
# 1517413            Kuambil Lagi Hatiku       0      2019      \N
# 1517426                Dankyavar Danka       0      2013      \N
# 1517428                         6 Gunn       0      2017      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes  \
# 8                   45                     Romance            5.4       216
# 144                100      Documentary,News,Sport            5.2       544
# 339                100                          \N            4.4        18
# 374                 70  Action,Adventure,Biography            6.0       952
# 384                 90                       Drama            5.7        29
# ...                ...                         ...            ...       ...
# 1517407             \N       Adventure,History,War            3.6        19
# 1517409             \N                      Comedy            8.9        19
# 1517413            123                       Drama            8.3         9
# 1517426             \N                      Comedy            7.7         9
# 1517428            116                       Drama            7.0        12
#
#          imdb_id
# 8              9
# 144          147
# 339          502
# 374          574
# 384          591
# ...          ...
# 1517407  9916428
# 1517409  9916460
# 1517413  9916538
# 1517426  9916706
# 1517428  9916730
#
# [497051 rows x 12 columns]

# %% [markdown]
# I want to check, if I can get the top-250 as on IMDB

# %%
df = df[df["startYear"] != "\\N"]
df
# Out:
#             tconst titleType                   primaryTitle  \
# 8        tt0000009     movie                     Miss Jerry
# 144      tt0000147     movie  The Corbett-Fitzsimmons Fight
# 339      tt0000502     movie                       Bohemios
# 374      tt0000574     movie    The Story of the Kelly Gang
# 384      tt0000591     movie               The Prodigal Son
# ...            ...       ...                            ...
# 1517407  tt9916428     movie            The Secret of China
# 1517409  tt9916460   tvMovie                      Pink Taxi
# 1517413  tt9916538     movie            Kuambil Lagi Hatiku
# 1517426  tt9916706     movie                Dankyavar Danka
# 1517428  tt9916730     movie                         6 Gunn
#
#                          originalTitle isAdult startYear endYear  \
# 8                           Miss Jerry       0      1894      \N
# 144      The Corbett-Fitzsimmons Fight       0      1897      \N
# 339                           Bohemios       0      1905      \N
# 374        The Story of the Kelly Gang       0      1906      \N
# 384                  L'enfant prodigue       0      1907      \N
# ...                                ...     ...       ...     ...
# 1517407   Hong xing zhao yao Zhong guo       0      2019      \N
# 1517409                      Pink Taxi       0      2019      \N
# 1517413            Kuambil Lagi Hatiku       0      2019      \N
# 1517426                Dankyavar Danka       0      2013      \N
# 1517428                         6 Gunn       0      2017      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes  \
# 8                   45                     Romance            5.4       216
# 144                100      Documentary,News,Sport            5.2       544
# 339                100                          \N            4.4        18
# 374                 70  Action,Adventure,Biography            6.0       952
# 384                 90                       Drama            5.7        29
# ...                ...                         ...            ...       ...
# 1517407             \N       Adventure,History,War            3.6        19
# 1517409             \N                      Comedy            8.9        19
# 1517413            123                       Drama            8.3         9
# 1517426             \N                      Comedy            7.7         9
# 1517428            116                       Drama            7.0        12
#
#          imdb_id
# 8              9
# 144          147
# 339          502
# 374          574
# 384          591
# ...          ...
# 1517407  9916428
# 1517409  9916460
# 1517413  9916538
# 1517426  9916706
# 1517428  9916730
#
# [496982 rows x 12 columns]

# %%
df[(df["numVotes"] > 100000) & (df["titleType"] == "movie")].nlargest(
    250, "averageRating"
)
# Out:
#             tconst titleType                               primaryTitle  \
# 84294    tt0111161     movie                   The Shawshank Redemption
# 47595    tt0068646     movie                              The Godfather
# 31248    tt0050083     movie                               12 Angry Men
# 50165    tt0071562     movie                      The Godfather Part II
# 81691    tt0108052     movie                           Schindler's List
# ...            ...       ...                                        ...
# 1142781  tt3315342     movie                                      Logan
# 1193638  tt3863552     movie                          Bajrangi Bhaijaan
# 1202448  tt4016934     movie                             The Handmaiden
# 1265234  tt5027774     movie  Three Billboards Outside Ebbing, Missouri
# 1286693  tt5323662     movie                  A Silent Voice: The Movie
#
#                                      originalTitle isAdult startYear endYear  \
# 84294                     The Shawshank Redemption       0      1994      \N
# 47595                                The Godfather       0      1972      \N
# 31248                                 12 Angry Men       0      1957      \N
# 50165                        The Godfather Part II       0      1974      \N
# 81691                             Schindler's List       0      1993      \N
# ...                                            ...     ...       ...     ...
# 1142781                                      Logan       0      2017      \N
# 1193638                          Bajrangi Bhaijaan       0      2015      \N
# 1202448                                  Ah-ga-ssi       0      2016      \N
# 1265234  Three Billboards Outside Ebbing, Missouri       0      2017      \N
# 1286693                             Koe no katachi       0      2016      \N
#
#         runtimeMinutes                   genres  averageRating  numVotes  \
# 84294              142                    Drama            9.3   2983880
# 47595              175              Crime,Drama            9.2   2082028
# 31248               96              Crime,Drama            9.0    902253
# 50165              202              Crime,Drama            9.0   1404719
# 81691              195  Biography,Drama,History            9.0   1495397
# ...                ...                      ...            ...       ...
# 1142781            137      Action,Drama,Sci-Fi            8.1    873394
# 1193638            163  Action,Adventure,Comedy            8.1    101980
# 1202448            145   Drama,Romance,Thriller            8.1    182430
# 1265234            115       Comedy,Crime,Drama            8.1    571587
# 1286693            130          Animation,Drama            8.1    111963
#
#          imdb_id
# 84294     111161
# 47595      68646
# 31248      50083
# 50165      71562
# 81691     108052
# ...          ...
# 1142781  3315342
# 1193638  3863552
# 1202448  4016934
# 1265234  5027774
# 1286693  5323662
#
# [250 rows x 12 columns]

# %% [markdown]
# And now I need a list of genres

# %%
genres = set()
for genre_list in df[df["genres"] != "\\N"]["genres"].unique():
    genres.update(genre_list.split(","))
genres
# Out:
# {'Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western'}
